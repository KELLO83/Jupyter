# %% [markdown]
# ### JupyTer Notebook
#
# 주피처 노트북은 웹브라우저상에서 개발가능 코드를 cell단위를 묶어서 실행하고
# 특히 데이터 관련 작업을 할때 많이 사용한다
#
# >교육을 위한 강의 노트로도 장점

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![%EC%95%B5%EB%AC%B4%EC%83%88.jpg](attachment:%EC%95%B5%EB%AC%B4%EC%83%88.jpg)

# %% [markdown]
# ## 특징
#
# 1.코드를 cell단위를 작성 및 실행
# 1.마크다운을 통한 문서화
# 1.그래프나 표 등을 실시간으로 확인
# 1.html.pdf 등 파일로 저장

# %% [markdown]
# ## 사전 학습 자료
#
# ---
#
# -다음링크에서 파이썬 기본편에대한 학습
# [나도코딩 블로그](https://www.youtube.com/watch?v=dJfq-eCi7KI&t=1545s)

# %%
# %%HTML
#
# <iframe width="500" height="300" src="https://www.youtube.com/embed/dJfq-eCi7KI" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## python 기본 문법

# %% [markdown]
# ## 모듈사용

# %% [markdown]
# ---
#
# ## 시각화 예제 1:그래프
#
# - matplitlip을 이용하면 다양한 그래프그리기 가능

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3]);  # Plot some data on the axes.

# %% [markdown]
# ## 시각화 예제 2:테이블
#
# - pandas 는 복작합 데이터를 분석할때 유용하다

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

df = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, np.nan],[19, 439, 6, 452, 226,232]],
                  index=pd.Index(['Tumour (Positive)', 'Non-Tumour (Negative)'], name='Actual Label:'),
                  columns=pd.MultiIndex.from_product([['Decision Tree', 'Regression', 'Random'],['Tumour', 'Non-Tumour']], names=['Model:', 'Predicted:']))
df.style

# %%
import random

random.randrange??

# %%
import collections

test=collections.deque()

collections.Counter?

# %%
number=3
print(number)
# Out:
# 3

# %%
number*=3
print(number)
# Out:
# 21

# %%
number+=5
print(number)
# Out:
# 7

# %%
number=2
b=3
print(number)
print(number+b)
# Out:
# 2
# 5
